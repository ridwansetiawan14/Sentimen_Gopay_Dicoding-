# %%
# !pip install google-play-scraper
# !pip install pandas
from google_play_scraper import Sort, reviews
import pandas as pd

app_id = 'com.gojek.gopay'  # ID untuk Gopay
lang = 'id'  # Bahasa Indonesia
country = 'id'  # Ulasan dari pengguna di Indonesia
batch_size = 2000  # Ukuran batch per request
total_reviews_to_scrape = 12500  # Jumlah ulasan yang ingin diambil

# List untuk menyimpan semua ulasan
all_reviews = []

# Variabel untuk melacak continuation_token
continuation_token = None

# Loop untuk mengambil ulasan dalam beberapa batch
while len(all_reviews) < total_reviews_to_scrape:
    result, continuation_token = reviews(
        app_id,
        lang=lang,
        country=country,
        sort=Sort.NEWEST,  # Mengambil ulasan terbaru, bisa juga Sort.MOST_RELEVANT atau Sort.RATING
        count=batch_size,
        continuation_token=continuation_token  # Lanjutkan scraping dari token terakhir
    )

    # Menambahkan ulasan ke dalam list
    all_reviews.extend(result)

    print(f'Scraped {len(all_reviews)} reviews so far...')

    # Jika tidak ada lagi continuation_token, berhenti
    if continuation_token is None:
        break

# Potong ulasan jika lebih dari yang diinginkan
all_reviews = all_reviews[:total_reviews_to_scrape]

# Konversi ke DataFrame
df = pd.DataFrame(all_reviews)

# Simpan ulasan ke file CSV
df.to_csv('gopayreviews.csv', index=False)

print(f'Successfully scraped {len(df)} reviews!')
# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 804.7 kB/s eta 0:00:00
# ...
# Scraped 2000 reviews so far...
# Scraped 4000 reviews so far...
# Scraped 6000 reviews so far...
# Scraped 8000 reviews so far...
# Scraped 10000 reviews so far...
# Scraped 12000 reviews so far...
# Scraped 14000 reviews so far...
# Successfully scraped 12500 reviews!
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
# Menampilkan semua kolom
pd.set_option('display.max_columns', None)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                reviewId       userName  \
# 0  d49949da-d9a7-400c-93c1-a73b4e491686    Agoez Ahmad
# 1  e9c9d00e-55a4-41c8-a257-387afea1bb55   Kurnia Wandi
# 2  f793671b-e5b3-4a38-837a-8da3faf43278  Irwan Saputra
# 3  4d0a7c51-afa8-4671-ae27-cd4e37913539   Idris Copler
# ...

# %%
# Menampilkan informasi ringkas tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12500 non-null  object
#  1   userName              12500 non-null  object
#  2   userImage             12500 non-null  object
#  3   content               12500 non-null  object
#  4   score                 12500 non-null  int64
#  5   thumbsUpCount         12500 non-null  int64
#  6   reviewCreatedVersion  10224 non-null  object
#  7   at                    12500 non-null  datetime64[ns]
#  8   replyContent          1575 non-null   object
#  9   repliedAt             1575 non-null   datetime64[ns]
#  10  appVersion            10224 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.0+ MB

# %%
# Menampilkan statistik deskriptif
df.describe()
# Out:
#               score  thumbsUpCount                             at  \
# count  12500.000000   12500.000000                          12500
# mean       4.300560       1.599680  2024-07-25 11:10:03.972880128
# min        1.000000       0.000000            2024-07-10 01:53:12
# 25%        5.000000       0.000000  2024-07-17 16:52:19.249999872
# 50%        5.000000       0.000000            2024-07-25 12:33:33
# 75%        5.000000       0.000000  2024-08-02 01:59:20.750000128
# max        5.000000   12983.000000            2024-08-09 14:28:37
# std        1.391049     117.400426                            NaN
#
#                            repliedAt
# count                           1575
# mean   2024-07-20 04:16:28.725714432
# min              2023-05-15 06:06:38
# 25%       2024-07-17 08:23:55.500000
# 50%              2024-07-25 04:52:59
# 75%       2024-08-01 14:01:58.500000
# max              2024-08-10 12:08:05
# std                              NaN

# %%
from google.colab import files

files.download('gopayreviews.csv')
